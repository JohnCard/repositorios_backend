# %% [markdown]
# # Actividad de Ejercicio - Listas

# %%
def buscar_indices(num):
    cont_dos = -1
    for u in my_shopping_cart:
        cont_dos += 1
        if(u[1] == num):
            my_shopping_cart[cont_dos][0] += cantidad[0]

def buscar_indices_dos(num):
    cont_dos = -1
    for u in my_shopping_cart:
        cont_dos += 1
        if(u[1] == num):
            my_shopping_cart[cont_dos][0] -= cantidad[0]

def recorrer_lista(my_shopping_cart,message):
    lista_productos = []
    if type(my_shopping_cart) == list:
        print(message)
        for element in my_shopping_cart:
            if(type(element) == list):
                product = ""
                if element[1] == 1:
                    mensaje = f'{element[0]} piezas de'
                    product = "Pan"
                if element[1] == 2:
                    mensaje = f'{element[0]} rebanadas de'
                    product = "Jamón"
                if element[1] == 3:
                    mensaje = f'{element[0]} envases de'
                    product = "Crema"
                if element[1] == 4:
                    mensaje = f'{element[0]} envases de'
                    product = "Mayonesa"
                if element[1] == 5:
                    mensaje = f'{element[0]} piezas de'
                    product = "Lechuga"
                if element[1] == 6:
                    mensaje = f'{element[0]} rebanadas de'
                    product = "Pastel"
                if element[1] == 7:
                    mensaje = f'{element[0]} unidades de'
                    product = "Cajas de leche"
                if element[1] == 8:
                    mensaje = f'{element[0]} piezas de'
                    product = "Manzana"
                if element[1] == 9:
                    mensaje = f'{element[0]} bolsitas de'
                    product = "Botana"
                if element[1] == 10:
                    mensaje = f'{element[0]} bolsas de'
                    product = "Papas"
                lista_productos.append(f"{mensaje} {product}")  
                print(f".- {mensaje} {product}\n")
                                    
    else:
        print("Formato incorrecto, debes ingresar una lista de listas")
    return lista_productos

lista_compras = []
print("Carrito de compras\n")
print("""
Productos Disponibles:
1.- Pan
2.- Jamón
3.- Crema
4.- Mayonesa
5.- Lechuga
6.- Pastel
7.- Caja de leche
8.- Manzana
9.- Botana
10.- Papas
""")
print("Ingresa una lista con los productos en este formato: [[Cantidad,Producto]]")
print("Por ejemplo: [[1,1], [3,2]] significa 1 Pan y 3 Jamón" )
my_shopping_cart = eval(input('Ingresala aqui por favor: '))
lista_indices = []
for i in my_shopping_cart:
    lista_indices.append(i[1])
lista_compras = ''
lista_compras = recorrer_lista(my_shopping_cart,'\n\nEn tu carrito hay:')
print(f'''A continuación le mostramos su lista de productos hasta ahora para que usted decida si desea seguir comprando
o incluso si lo ve necesario, retirar algunos de ellos: {lista_compras}''')
print('Si es que aun desea modificar su lista de articulos digite 1), y si es que desea terminar con su compra digite 2)')
answer = input('Digite su respuesta aqui porfavore (1/2): ')
while(answer == '1'):
    print(f'Estado actual de su carrito: {lista_compras}')
    answer = input('Digite a) si es que desea agregar algo mas a su carrito o b) para quitar algo (a/b): ')
    if(answer == 'a'):
        print("""
Productos Disponibles:
1.- Pan
2.- Jamón
3.- Crema
4.- Mayonesa
5.- Lechuga
6.- Pastel
7.- Caja de leche
8.- Manzana
9.- Botana
10.- Papas
            """)
        productos_nuevos = eval(input("Ingresa una lista con los productos en el formato mostrado en el inicio ([[Cantidad,Producto]]): "))
        # recorrer_lista(productos_nuevos,'\nEn tu carrito ahora hay:')
        for cantidad in productos_nuevos:
            if((cantidad[1] not in lista_indices) == True):
                my_shopping_cart.append(cantidad)
            else:
                if(cantidad[1] == 1):
                    buscar_indices(1)
                elif(cantidad[1] == 2):
                    buscar_indices(2)
                elif(cantidad[1] == 3):
                    buscar_indices(3)
                elif(cantidad[1] == 4):
                    buscar_indices(4)
                elif(cantidad[1] == 5):
                    buscar_indices(5)
                elif(cantidad[1] == 6):
                    buscar_indices(6)
                elif(cantidad[1] == 7):
                    buscar_indices(7)
                elif(cantidad[1] == 8):
                    buscar_indices(8)
                elif(cantidad[1] == 9):
                    buscar_indices(9)
                elif(cantidad[1] == 10):
                    buscar_indices(10)
        lista_compras = recorrer_lista(my_shopping_cart,'\nAhora en tu carrito hay:')
        answer = input('Si desea intentar de nuevo digite 1, si desea terminar su compra digie 2 (1/2): ')
    else:
        print('''Digite una lista con el formato ya mostrado que indicará las cantidades y los indices de los productos que serán retirados
del carrito, por ejemplo, si en su carrito actualmente hubiesen 3 piezas de pan y usted digitase [[1,1]], se quedaria el carrito con solo 2
piezas de pan''')
        lista_quitar = eval(input('Digite la lista aqui por favor: '))
        for cantidad in lista_quitar:
            if(cantidad[1] == 1):
                buscar_indices_dos(1)
            elif(cantidad[1] == 2):
                buscar_indices_dos(2)
            elif(cantidad[1] == 3):
                buscar_indices_dos(3)
            elif(cantidad[1] == 4):
                buscar_indices_dos(4)
            elif(cantidad[1] == 5):
                buscar_indices_dos(5)
            elif(cantidad[1] == 6):
                buscar_indices_dos(6)
            elif(cantidad[1] == 7):
                buscar_indices_dos(7)
            elif(cantidad[1] == 8):
                buscar_indices_dos(8)
            elif(cantidad[1] == 9):
                buscar_indices_dos(9)
            elif(cantidad[1] == 10):
                buscar_indices_dos(10)
        lista_compras = recorrer_lista(my_shopping_cart,'\n Ahora en tu carrito hay:')
        answer = input('Si desea intentar de nuevo digite 1, si desea terminar su compra digie 2 (1/2): ')
print('Gracias por su visita, adios! ;).')
# Out:
# Carrito de compras
#
#
# Productos Disponibles:
# 1.- Pan
# 2.- Jamón
# 3.- Crema
# 4.- Mayonesa
# 5.- Lechuga
# 6.- Pastel
# 7.- Caja de leche
# 8.- Manzana
# 9.- Botana
# 10.- Papas
#
# Ingresa una lista con los productos en este formato: [[Cantidad,Producto]]
# Por ejemplo: [[1,1], [3,2]] significa 1 Pan y 3 Jamón
# Ingresala aqui por favor: [[2,3],[1,10]]
#
#
# En tu carrito hay:
# .- 2 envases de Crema
#
# .- 1 bolsas de Papas
#
# A continuación le mostramos su lista de productos hasta ahora para que usted decida si desea seguir comprando
# o incluso si lo ve necesario, retirar algunos de ellos: ['2 envases de Crema', '1 bolsas de Papas']
# Si es que aun desea modificar su lista de articulos digite 1), y si es que desea terminar con su compra digite 2)
# Digite su respuesta aqui porfavore (1/2): 1
# Estado actual de su carrito: ['2 envases de Crema', '1 bolsas de Papas']
# Digite a) si es que desea agregar algo mas a su carrito o b) para quitar algo (a/b): a
#
# ...
